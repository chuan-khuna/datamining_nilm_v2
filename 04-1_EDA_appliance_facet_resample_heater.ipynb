# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt

sns.set(context="paper", style="whitegrid", 
       rc={
           "figure.figsize": (21, 9),
           "figure.dpi": 100
       })
google = ["#4285F4", "#DB4437", "#F4B400", "#0F9D58"]

sns.set_palette(google)

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv("./data/AMPDs2.csv")
df['TIMESTAMP'] = pd.to_datetime(df['TIMESTAMP'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22075200 entries, 0 to 22075199
# Data columns (total 8 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   TIMESTAMP              datetime64[ns]
#  1   power factor_apparent  float64
#  2   power_reactive         float64
#  3   power_active           float64
#  4   power_apparent         float64
#  5   appliances_type        object
#  6   appliances_id          int64
#  7   appliances_name        object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(2)
# memory usage: 1.3+ GB

# %%
df.head()
# Out:
#             TIMESTAMP  power factor_apparent  power_reactive  power_active  \
# 0 2012-04-01 00:00:00                   0.93           141.0         918.0
# 1 2012-04-01 00:01:00                   0.93           141.0         913.0
# 2 2012-04-01 00:02:00                   0.93           139.0         872.0
# 3 2012-04-01 00:03:00                   0.93           141.0         872.0
# 4 2012-04-01 00:04:00                   0.89           140.0         772.0
#
#    power_apparent appliances_type  appliances_id appliances_name
# 0          1066.0            main              1          main 1
# 1          1056.0            main              1          main 1
# 2          1021.0            main              1          main 1
# 3          1018.0            main              1          main 1
# 4          1018.0            main              1          main 1

# %%
main_df = df[df['appliances_type'] == 'main']

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1051200 entries, 0 to 1051199
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   TIMESTAMP              1051200 non-null  datetime64[ns]
#  1   power factor_apparent  1051200 non-null  float64
#  2   power_reactive         1051200 non-null  float64
#  3   power_active           1051200 non-null  float64
#  4   power_apparent         1051200 non-null  float64
#  5   appliances_type        1051200 non-null  object
#  6   appliances_id          1051200 non-null  int64
#  7   appliances_name        1051200 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(2)
# memory usage: 72.2+ MB

# %%
df = df.drop(index=main_df.index)

# %%
df = df.reset_index().drop(columns=['index'], axis=1)
df.head()
# Out:
#             TIMESTAMP  power factor_apparent  power_reactive  power_active  \
# 0 2012-04-01 00:00:00                    0.0             0.0           0.0
# 1 2012-04-01 00:01:00                    0.0             0.0           0.0
# 2 2012-04-01 00:02:00                    0.0             0.0           0.0
# 3 2012-04-01 00:03:00                    0.0             0.0           0.0
# 4 2012-04-01 00:04:00                    0.0             0.0           0.0
#
#    power_apparent appliances_type  appliances_id appliances_name
# 0             9.0           light              1         light 1
# 1             9.0           light              1         light 1
# 2             9.0           light              1         light 1
# 3             9.0           light              1         light 1
# 4             9.0           light              1         light 1

# %% [markdown]
# ### Data sampling period

# %%
sampling_period = int((df['TIMESTAMP'][1] - df['TIMESTAMP'][0]).total_seconds()/60)
sampling_period
# Out:
# 1

# %%
oneday_n = 24*60//sampling_period
oneday_n
# Out:
# 1440

# %%
oneweek_n = oneday_n*7
oneweek_n
# Out:
# 10080

# %% [markdown]
# ### Add new column
#
# `weekday`: monday = 0, sunday = 6

# %%
df['weekday'] = df['TIMESTAMP'].dt.weekday
df['month'] = df['TIMESTAMP'].dt.month

df['day_minute'] = (df['TIMESTAMP'].dt.hour*60) + (df['TIMESTAMP'].dt.minute)
df['week_minute'] = (df['weekday']*oneday_n) + df['day_minute']

# %%
df.head()
# Out:
#             TIMESTAMP  power factor_apparent  power_reactive  power_active  \
# 0 2012-04-01 00:00:00                    0.0             0.0           0.0
# 1 2012-04-01 00:01:00                    0.0             0.0           0.0
# 2 2012-04-01 00:02:00                    0.0             0.0           0.0
# 3 2012-04-01 00:03:00                    0.0             0.0           0.0
# 4 2012-04-01 00:04:00                    0.0             0.0           0.0
#
#    power_apparent appliances_type  appliances_id appliances_name  weekday  \
# 0             9.0           light              1         light 1        6
# 1             9.0           light              1         light 1        6
# 2             9.0           light              1         light 1        6
# 3             9.0           light              1         light 1        6
# 4             9.0           light              1         light 1        6
#
#    month  day_minute  week_minute
# 0      4           0         8640
# 1      4           1         8641
# 2      4           2         8642
# 3      4           3         8643
# 4      4           4         8644

# %%
main_df['weekday'] = main_df['TIMESTAMP'].dt.weekday
main_df['month'] = main_df['TIMESTAMP'].dt.month

main_df['day_minute'] = (main_df['TIMESTAMP'].dt.hour*60) + (main_df['TIMESTAMP'].dt.minute)
main_df['week_minute'] = (main_df['weekday']*oneday_n) + main_df['day_minute']

# %%
main_df.head()
# Out:
#             TIMESTAMP  power factor_apparent  power_reactive  power_active  \
# 0 2012-04-01 00:00:00                   0.93           141.0         918.0
# 1 2012-04-01 00:01:00                   0.93           141.0         913.0
# 2 2012-04-01 00:02:00                   0.93           139.0         872.0
# 3 2012-04-01 00:03:00                   0.93           141.0         872.0
# 4 2012-04-01 00:04:00                   0.89           140.0         772.0
#
#    power_apparent appliances_type  appliances_id appliances_name  weekday  \
# 0          1066.0            main              1          main 1        6
# 1          1056.0            main              1          main 1        6
# 2          1021.0            main              1          main 1        6
# 3          1018.0            main              1          main 1        6
# 4          1018.0            main              1          main 1        6
#
#    month  day_minute  week_minute
# 0      4           0         8640
# 1      4           1         8641
# 2      4           2         8642
# 3      4           3         8643
# 4      4           4         8644

# %% [markdown]
# ### get top appliances by power consumption

# %%
top_power_consump = df[df["power_active"] >= 40]\
    .groupby(["appliances_name"])\
    .mean()\
    .sort_values("power_active", ascending=False)\
    .reset_index()['appliances_name'].tolist()

# %%
top_power_consump
# Out:
# ['unknown 1',
#  'heat pump 1',
#  'electric oven 1',
#  'unknown 3',
#  'light 1',
#  'light 3',
#  'unknown 7',
#  'sockets 2',
#  'unknown 9',
#  'unknown 2',
#  'unknown 4',
#  'television 1',
#  'fridge 1',
#  'unknown 6',
#  'light 2',
#  'light 4',
#  'sockets 3',
#  'unknown 8',
#  'sockets 1',
#  'unknown 5']

# %% [markdown]
# ## EDA

# %%
# select top appliance
top_k = 10
num_appliance = len(top_power_consump)
power_col = 'power_active'

# %% [markdown]
# ### resample

# %%
resample_min = 10

appliance_name = 'heat pump 1'

re_df = df[df['appliances_name'] == appliance_name].copy()
re_df.index = re_df['TIMESTAMP']
re_df = re_df.resample(f"{resample_min}min").mean().reset_index()
re_df.head()
# Out:
#             TIMESTAMP  power factor_apparent  power_reactive  power_active  \
# 0 2012-04-01 00:00:00                  0.711            17.2          36.7
# 1 2012-04-01 00:10:00                  0.895           213.0        1193.1
# 2 2012-04-01 00:20:00                  0.980           317.7        1791.4
# 3 2012-04-01 00:30:00                  0.696           229.8        1268.2
# 4 2012-04-01 00:40:00                  0.040             8.0           0.8
#
#    power_apparent  appliances_id  weekday  month  day_minute  week_minute
# 0            52.0            1.0      6.0    4.0         4.5       8644.5
# 1          1227.1            1.0      6.0    4.0        14.5       8654.5
# 2          1834.3            1.0      6.0    4.0        24.5       8664.5
# 3          1305.5            1.0      6.0    4.0        34.5       8674.5
# 4            24.4            1.0      6.0    4.0        44.5       8684.5

# %%
re_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105120 entries, 0 to 105119
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   TIMESTAMP              105120 non-null  datetime64[ns]
#  1   power factor_apparent  105120 non-null  float64
#  2   power_reactive         105120 non-null  float64
#  3   power_active           105120 non-null  float64
#  4   power_apparent         105120 non-null  float64
#  5   appliances_id          105120 non-null  float64
#  6   weekday                105120 non-null  float64
#  7   month                  105120 non-null  float64
#  8   day_minute             105120 non-null  float64
#  9   week_minute            105120 non-null  float64
# dtypes: datetime64[ns](1), float64(9)
# memory usage: 8.0 MB

# %%
re_df = re_df.groupby(['month', 'week_minute']).mean().reset_index()
re_df['month'] = re_df['month'].astype(int)

re_df.head()
# Out:
#    month  week_minute  power factor_apparent  power_reactive  power_active  \
# 0      1          4.5               0.712875         17.8250       37.9500
# 1      1         14.5               0.710750         17.8250       38.0125
# 2      1         24.5               0.714875         18.0500       38.2750
# 3      1         34.5               0.714250         18.1000       38.4000
# 4      1         44.5               0.710125         18.0875       38.3625
#
#    power_apparent  appliances_id  weekday  day_minute
# 0         53.5375            1.0      0.0         4.5
# 1         53.7750            1.0      0.0        14.5
# 2         53.8625            1.0      0.0        24.5
# 3         54.0500            1.0      0.0        34.5
# 4         54.2500            1.0      0.0        44.5

# %%
re_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12096 entries, 0 to 12095
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   month                  12096 non-null  int32
#  1   week_minute            12096 non-null  float64
#  2   power factor_apparent  12096 non-null  float64
#  3   power_reactive         12096 non-null  float64
#  4   power_active           12096 non-null  float64
#  5   power_apparent         12096 non-null  float64
#  6   appliances_id          12096 non-null  float64
#  7   weekday                12096 non-null  float64
#  8   day_minute             12096 non-null  float64
# dtypes: float64(8), int32(1)
# memory usage: 803.4 KB

# %%
def label(x, color, label):
    ax = plt.gca()
    ax.text(0.01, 0.1,
           int(label),
           fontweight="bold",
           color=color,
           size=22,
           ha="left",
           va="center",
           transform=ax.transAxes)


sns.set(context="paper", style="white", 
       rc={
           "figure.figsize": (42, 9),
           "figure.dpi": 150,
           "axes.facecolor": (0, 0, 0, 0)
       })
sns.set_palette("plasma", 18)

g = sns.FacetGrid(re_df,
                  row='month',
                  hue='month',
                  aspect=21,
                  height=1.5)

g.map(sns.lineplot, "week_minute", "power_active", lw=1, alpha=1)
g.map(plt.fill_between, "week_minute", "power_active", alpha=0.15)
g.map(plt.axhline, y=0, lw=0.75, alpha=0.5)
g.map(label, "month")
g.fig.subplots_adjust(hspace= -0.60)
g.set_titles("")
g.despine(bottom=True, left=True)
g.set(yticks=[])
g.set(xticks=np.arange(0, oneweek_n+oneday_n/2, oneday_n/2))


plt.suptitle(f"Monthly/Weekly {appliance_name} Power Consumption \n sampling period {resample_min} min")
plt.xlabel("minute of week")
plt.savefig("./visualization_output/04_facet_grid_resample_heatpump.png", dpi=250)
